# %%
import torch
import numpy as np
import pickle
import matplotlib.pyplot as plt
from wave_manifold.layers import Retina
from wave_manifold import preprocessing

# %%
retina_file = open('../data/pretraining_retina.pkl', 'rb')
retina = pickle.load(retina_file)
retina_file.close()

# %%
retinal_mnist = preprocessing.RetinalMNIST(retina, train=False)

# %%
retinal_mnist.project_data_onto_retina(equal_samples_per_class=False, create_dict=True)
# Out:
# Processed image 0 out of 10000
# Processed image 1000 out of 10000
# Processed image 2000 out of 10000
# Processed image 3000 out of 10000
# Processed image 4000 out of 10000
# Processed image 5000 out of 10000
# Processed image 6000 out of 10000
# Processed image 7000 out of 10000
# Processed image 8000 out of 10000
# Processed image 9000 out of 10000

# %%
retinal_mnist.retinal_imageset.shape
# Out:
# torch.Size([3200, 10000])

# %%
torch.save(retinal_mnist.raw_data, '../data/raw_mnist_train.pt')
# torch.save(retinal_mnist.retinal_imageset_dict, '../data/retinal_mnist_train_dict.pt')
# torch.save(retinal_mnist.targets, '../data/retinal_mnist_train_targets.pt')

# %%
import itertools

# %%
class_idx_list = list(itertools.chain.from_iterable(list(retinal_mnist.class_idxs.values())))

# %%
len(retinal_mnist.targets[class_idx_list])
# Out:
# 10000

# %%
torch.save(retinal_mnist.targets[class_idx_list], 'retinal_mnist_test_targets.pt')

# %%
idx = 950
plt.scatter(retina.pos[:,1], retina.pos[:,0], marker='.', color='k')
plt.scatter(retina.pos[:,1][retinal_mnist.retinal_imageset[:,idx] > 0], retina.pos[:,0][retinal_mnist.retinal_imageset[:,idx] > 0], marker='.', color='r')
# print('label: {}'.format(retinal_mnist.targets[idx]))
plt.gca().invert_yaxis()
plt.xticks([])
plt.yticks([])
# plt.gca().invert_xaxis()
# Out:
# ([], [])

# %%
import manifold_analysis

# %%
f

# %%
fig, ax = plt.figure()
plt.imshow(retinal_mnist.raw_data[170,:,:])
ax.set_xticks([])
# plt.xticks([])

# plt.yticks([])

# %%
idx = 1510
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
axs.ravel()[0].imshow(retinal_mnist.raw_data[idx,:,:])
axs.ravel()[0].set_xticks([])
axs.ravel()[0].set_yticks([])
axs.ravel()[0].set_xticklabels([])
axs.ravel()[0].set_yticklabels([])

axs.ravel()[1].scatter(retina.pos[:,1], retina.pos[:,0], marker='.', color='k')
axs.ravel()[1].scatter(retina.pos[:,1][retinal_mnist.retinal_imageset[:,idx] > 0], retina.pos[:,0][retinal_mnist.retinal_imageset[:,idx] > 0], marker='.', color='r')
axs.ravel()[1].invert_yaxis()
axs.ravel()[1].set_xticks([])
axs.ravel()[1].set_yticks([])
axs.ravel()[1].set_xticklabels([])
axs.ravel()[1].set_yticklabels([])

# %%
retinal_mnist.targets

# %%
retinal_mnist.retinal_imageset.shape
